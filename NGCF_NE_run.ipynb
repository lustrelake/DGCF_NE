# %% [markdown]
# # DGCF_NE

# %%
# %reset
import os
os.chdir('/content/drive/MyDrive/code/disenhance2')#工作路径

# %%
# %run /content/drive/MyDrive/code/disenhance2/disen5.5early.py  --dataset 'dblp' \
--d 128  --lr 0.005 --nlayer 5 --k 4 --routit 3 --b 0.1 --nbsz 128
# Out:
# ========== 处理数据 ===========
# len(ditem), len(item),Rmat.size,G.shape:
#  17699 1177 17699 torch.Size([6001, 1177])
# ========== 同构矩阵nx图 ===========
# 节点数量： 6001
# 节点数量： 1177
# u0.shape,v0.shape torch.Size([6001, 128]) torch.Size([1177, 128])
# ========== 模型 ===========
# 11111self.u.weight.data.shape,self.v.weight.data.shape torch.Size([6001, 128]) torch.Size([1177, 128])
# ========== 迭代训练 ===========
# +++第 0次loss: 0.0725
# f1: 0.13266599470752463 map: 0.2228759756016336 mrr: 0.3735126994723125 mndcg: 0.29130676358566476
# +++第 1次loss: 0.0623
# f1: 0.13538906687118196 map: 0.22425268197943285 mrr: 0.3782054644287622 mndcg: 0.2944143040115698
# +++第 2次loss: 0.0546
# f1: 0.13706325646933543 map: 0.22700392736212338 mrr: 0.3835084345264588 mndcg: 0.2977667748214998
# +++第 3次loss: 0.0478
# f1: 0.13817760742152124 map: 0.2290171328631338 mrr: 0.38847272553881373 mndcg: 0.3004193123013542
# +++第 4次loss: 0.0416
# ...

# %% [markdown]
# 第18次迭代结果
# loss: 0.0128
#
# f1: 0.1440713764315199 map: 0.23390256085127045 mrr: 0.3953946531883784 mndcg: 0.3068996094950648
